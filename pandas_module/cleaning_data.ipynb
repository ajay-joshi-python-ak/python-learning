# %%
import pandas as pd
import numpy as np

data = {
        'CustomerID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
        'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'George', 'Hannah', 'Ivy', 'Jack'],
        'Age': [25, 30, None, 45, 21, 34, 40, 28, 31, 26],
        'Gender': ['Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'MALE'],
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
        'PurchaseAmount': [150.50, 200.00, np.nan, 50.75, 120.00, -30.00, 8000.00, 45.20, 100.00, 90.00],
        'JoinDate': ['2023-01-15', '2023/02/20', 'Jan 1, 2024', '2023-04-10', '2023-05-05', '2023-01-15', '2023-07-30', '2023-08-25', '2023-09-19', '2023-10-14'],
        'Email': ['alice@example.com', 'bob@example.com', 'charlie@test.com', 'david@example.com', 'eve@test.com', 'frank@example.com', 'george@example.com', 'hannah@test.com', 'ivy@example.com', 'jack@example.com'],
        'Status': ['Active', 'Active', 'Inactive', 'Active', 'Active', 'Active', 'Active', 'Active', 'Active', 'Active']
    }
    
df = pd.DataFrame(data)

display(df)
# Out:
#    CustomerID     Name   Age  Gender         City  PurchaseAmount  \
# 0         101    Alice  25.0  Female     New York          150.50
# 1         102      Bob  30.0    Male  Los Angeles          200.00
# 2         103  Charlie   NaN    Male      Chicago             NaN
# 3         104    David  45.0    Male      Houston           50.75
# 4         105      Eve  21.0  Female      Phoenix          120.00
# 5         106    Frank  34.0    Male     New York          -30.00
# 6         107   George  40.0    Male  Los Angeles         8000.00
# 7         108   Hannah  28.0  Female      Chicago           45.20
# 8         109      Ivy  31.0  Female      Houston          100.00
# 9         110     Jack  26.0    MALE      Phoenix           90.00
#
#       JoinDate               Email    Status
# 0   2023-01-15   alice@example.com    Active
# 1   2023/02/20     bob@example.com    Active
# 2  Jan 1, 2024    charlie@test.com  Inactive
# 3   2023-04-10   david@example.com    Active
# ...

# %%
df['Gender'] = df['Gender'].str.lower()
df['Gender']
# Out:
# 0    female
# 1      male
# 2      male
# 3      male
# 4    female
# 5      male
# 6      male
# 7    female
# 8    female
# 9      male
# Name: Gender, dtype: object

# %%
df = df.replace('female', 'Female')
df = df.replace('male', 'Male')
df['Gender']
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# 5      Male
# 6      Male
# 7    Female
# 8    Female
# 9      Male
# Name: Gender, dtype: object

# %%
df['Age'].isna().sum()
# Out:
# np.int64(1)

# %%
df['Age']  = df['Age'].fillna(df['Age'].mode()).astype(int)
df['Age']
# Out:
# 0    25
# 1    30
# 2    26
# 3    45
# 4    21
# 5    34
# 6    40
# 7    28
# 8    31
# 9    26
# Name: Age, dtype: int64

# %%
df['PurchaseAmount'] = df['PurchaseAmount'].fillna(df['PurchaseAmount'].mean())
df
# Out:
#    CustomerID     Name  Age  Gender         City  PurchaseAmount     JoinDate  \
# 0         101    Alice   25  Female     New York      150.500000   2023-01-15
# 1         102      Bob   30    Male  Los Angeles      200.000000   2023/02/20
# 2         103  Charlie   26    Male      Chicago      969.605556  Jan 1, 2024
# 3         104    David   45    Male      Houston       50.750000   2023-04-10
# 4         105      Eve   21  Female      Phoenix      120.000000   2023-05-05
# 5         106    Frank   34    Male     New York      -30.000000   2023-01-15
# 6         107   George   40    Male  Los Angeles     8000.000000   2023-07-30
# 7         108   Hannah   28  Female      Chicago       45.200000   2023-08-25
# 8         109      Ivy   31  Female      Houston      100.000000   2023-09-19
# 9         110     Jack   26    Male      Phoenix       90.000000   2023-10-14
#
#                 Email    Status
# 0   alice@example.com    Active
# 1     bob@example.com    Active
# ...

# %%
df[df['PurchaseAmount']<0]
# Out:
#    CustomerID   Name  Age Gender      City  PurchaseAmount    JoinDate  \
# 5         106  Frank   34   Male  New York           -30.0  2023-01-15
#
#                Email  Status
# 5  frank@example.com  Active

# %%
df.loc[df['PurchaseAmount']<0, 'PurchaseAmount'] = df['PurchaseAmount'].mean()
df
# Out:
#    CustomerID     Name  Age  Gender         City  PurchaseAmount     JoinDate  \
# 0         101    Alice   25  Female     New York      150.500000   2023-01-15
# 1         102      Bob   30    Male  Los Angeles      200.000000   2023/02/20
# 2         103  Charlie   26    Male      Chicago      969.605556  Jan 1, 2024
# 3         104    David   45    Male      Houston       50.750000   2023-04-10
# 4         105      Eve   21  Female      Phoenix      120.000000   2023-05-05
# 5         106    Frank   34    Male     New York      969.605556   2023-01-15
# 6         107   George   40    Male  Los Angeles     8000.000000   2023-07-30
# 7         108   Hannah   28  Female      Chicago       45.200000   2023-08-25
# 8         109      Ivy   31  Female      Houston      100.000000   2023-09-19
# 9         110     Jack   26    Male      Phoenix       90.000000   2023-10-14
#
#                 Email    Status
# 0   alice@example.com    Active
# 1     bob@example.com    Active
# ...

# %%
df[df['PurchaseAmount']<0]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Name, Age, Gender, City, PurchaseAmount, JoinDate, Email, Status]
# Index: []

# %%
df['City']
# Out:
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4        Phoenix
# 5       New York
# 6    Los Angeles
# 7        Chicago
# 8        Houston
# 9        Phoenix
# Name: City, dtype: object

# %%
df['JoinDate'] = pd.to_datetime(df['JoinDate'], errors='coerce', format='mixed')
df['JoinDate']
# Out:
# 0   2023-01-15
# 1   2023-02-20
# 2   2024-01-01
# 3   2023-04-10
# 4   2023-05-05
# 5   2023-01-15
# 6   2023-07-30
# 7   2023-08-25
# 8   2023-09-19
# 9   2023-10-14
# Name: JoinDate, dtype: datetime64[ns]

# %%
df
# Out:
#    CustomerID     Name  Age  Gender         City  PurchaseAmount   JoinDate  \
# 0         101    Alice   25  Female     New York      150.500000 2023-01-15
# 1         102      Bob   30    Male  Los Angeles      200.000000 2023-02-20
# 2         103  Charlie   26    Male      Chicago      969.605556 2024-01-01
# 3         104    David   45    Male      Houston       50.750000 2023-04-10
# 4         105      Eve   21  Female      Phoenix      120.000000 2023-05-05
# 5         106    Frank   34    Male     New York      969.605556 2023-01-15
# 6         107   George   40    Male  Los Angeles     8000.000000 2023-07-30
# 7         108   Hannah   28  Female      Chicago       45.200000 2023-08-25
# 8         109      Ivy   31  Female      Houston      100.000000 2023-09-19
# 9         110     Jack   26    Male      Phoenix       90.000000 2023-10-14
#
#                 Email    Status
# 0   alice@example.com    Active
# 1     bob@example.com    Active
# 2    charlie@test.com  Inactive
# ...
